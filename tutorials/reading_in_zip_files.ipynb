# %% [markdown]
# <a href="https://colab.research.google.com/github/scottspurlock/csc4466-2022s/blob/main/tutorials/reading_in_zip_files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade --no-cache-dir gdown

# %%
import gdown

# Make sure to share the file you want to get from drive so anyone can access it.
# The shared URL might look like this:
shared_file_url = 'https://drive.google.com/file/d/1NPjoulV3fFxe5y2NWNqcLUjSWzPJckaX/view?usp=sharing'
# We just need the ID from the middle of the URL:
id = '1NPjoulV3fFxe5y2NWNqcLUjSWzPJckaX'
# Name the output file
output = 'data.zip'
# Call gdown to get the file
gdown.download(id=id, output=output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1NPjoulV3fFxe5y2NWNqcLUjSWzPJckaX
# To: /content/data.zip
# 100%|██████████| 12.2M/12.2M [00:00<00:00, 113MB/s]
# 'data.zip'

# %%
# Unzip the file if needed
# !unzip data.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/not_bird/0000.jpg
#   inflating: data/not_bird/0001.jpg
#   inflating: data/not_bird/0002.jpg
#   inflating: data/not_bird/0003.jpg
#   inflating: data/not_bird/0004.jpg
#   inflating: data/not_bird/0005.jpg
#   inflating: data/not_bird/0006.jpg
#   inflating: data/not_bird/0007.jpg
#   inflating: data/not_bird/0008.jpg
#   inflating: data/not_bird/0009.jpg
#   inflating: data/not_bird/0010.jpg
#   inflating: data/not_bird/0011.jpg
#   inflating: data/not_bird/0012.jpg
#   inflating: data/not_bird/0013.jpg
#   inflating: data/not_bird/0014.jpg
#   inflating: data/not_bird/0015.jpg
#   inflating: data/not_bird/0016.jpg
#   inflating: data/not_bird/0017.jpg
#   inflating: data/not_bird/0018.jpg
#   inflating: data/not_bird/0019.jpg
#   inflating: data/not_bird/0020.jpg
#   inflating: data/not_bird/0021.jpg
#   inflating: data/not_bird/0022.jpg
#   inflating: data/not_bird/0023.jpg
# ...
